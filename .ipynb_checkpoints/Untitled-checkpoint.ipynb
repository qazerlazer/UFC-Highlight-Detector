# %%
import os

folders = [
    "data/highlight",
    "data/non_highlight",
    "videos",
    "clips_raw",
    "notebooks"
]

for f in folders:
    os.makedirs(f, exist_ok=True)

print("✔ Folder structure created!")
# Out:
# ✔ Folder structure created!
